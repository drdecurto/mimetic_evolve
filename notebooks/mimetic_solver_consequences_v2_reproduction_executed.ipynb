# %% [markdown]
# # Weighted-system and linear-solver consequences
#
# This notebook is a thin, portable front end to the authoritative repository script. It makes no model calls and does not rerun discovery. The forced-CG branch is a diagnostic that solves a symmetrized surrogate system; it is not a recommended solver or a speed comparison.

# %%
from pathlib import Path
import subprocess, sys
import pandas as pd

HERE = Path.cwd().resolve()
ROOT = HERE.parent if HERE.name == "notebooks" else HERE
if not (ROOT / "scripts" / "analyze_solver_consequences_v2.py").exists():
    raise RuntimeError("Run this notebook from the repository root or notebooks/ directory")
print("repository root:", ROOT)
# Out:
# repository root: /mnt/data/_solver_diag_update/repo/Verifier_Guided_Mimetic_Operators_Reproducibility_Package_Scientific_Reports_Solver_Consequence_Update

# %%
subprocess.run([
    sys.executable,
    str(ROOT / "scripts" / "analyze_solver_consequences_v2.py"),
    "--root", str(ROOT),
], check=True)
print("authoritative analysis completed")
# Out:
# {
#   "all_released_exact_symmetry_residual_range": [
#     7.859842797555654e-17,
#     1.2320723772556416e-16
#   ],
#   "analysis": "solver_consequences_v2",
#   "followup_cg_applicable": 3,
#   "followup_exact": 3,
#   "four_primary_symmetry_residual_range": [
#     8.527437494769012e-17,
#     1.2320723772556416e-16
#   ],
#   "interpretation": "The symmetric-part CG run is a diagnostic that quantifies the consequence of treating a nonsymmetric weighted operator as symmetric. It is not a recommended solver and is not evidence that the reference systems are unsolvable. Dense direct solves, GMRES, and BiCGSTAB reproduce the original nonsymmetric systems; the large forced-CG error is introduced by symmetrization. Iteration counts are not used for cross-family speed claims.",
#   "operators": 11,
#   "order6_reference": {
#     "diagnostic_cg_solution_error": 0.27836556195491635,
#     "direct_solution_error": 1.002510282683709e-09,
#     "gmres_solution_error": 1.0147343054966979e-09,
#     "min_eigenvalue_symmetric_part": -26.000484784797088,
#     "symmetry_residual": 0.522351240707882
#   },
#   "order8_reference": {
#     "diagnostic_cg_solution_error": 0.3687853465724258,
#     "gmres_solution_error": 2.483241315470678e-11,
#     "min_eigenvalue_symmetric_part": -844.8656645590282,
#     "symmetry_residual": 0.8900549283678426
#   },
#   "primary_backward_euler_cg_applicable": 4,
#   "primary_cg_applicable": 4,
#   "primary_diagnostic_solution_error_max": 5.871696059235647e-06,
#   "primary_exact": 4,
#   "reference_backward_euler_cg_applicable_native_quadrature": 0,
#   "reference_cg_applicable_native_quadrature": 0,
#   "reference_symmetry_residuals": {
#     "reference_mole_k2_m200": 0.07195408441939963,
#     "reference_mole_k4_m200": 0.14851456664157534,
#     "reference_mole_k6_m200": 0.522351240707882,
#     "reference_mole_k8_m200": 0.8900549283678426
#   },
#   "references": 4,
#   "released_exact": 7,
#   "released_exact_cg_applicable": 7
# }
# authoritative analysis completed

# %%
OUT = ROOT / "derived" / "solver_consequences_v2"
headline = pd.read_csv(OUT / "headline_solver_consequences.csv")
headline
# Out:
#                                          quantity         value         units
# 0                    released_exact_constructions  7.000000e+00     operators
# 1                    released_exact_cg_applicable  7.000000e+00     operators
# 2       reference_cg_applicable_native_quadrature  0.000000e+00     operators
# 3     order6_reference_weighted_symmetry_residual  5.223512e-01      relative
# 4  order6_reference_min_symmetric_part_eigenvalue -2.600048e+01  matrix units
# 5   order6_reference_diagnostic_cg_solution_error  2.783656e-01      relative
# 6          order6_reference_direct_solution_error  1.002510e-09      relative
# 7           order6_reference_gmres_solution_error  1.014734e-09      relative
# 8   order8_reference_diagnostic_cg_solution_error  3.687853e-01      relative

# %%
availability = pd.read_csv(OUT / "tables" / "symmetric_system_availability.csv")
availability[[
    "operator", "family", "symmetry_residual",
    "min_eigenvalue_symmetric_part", "cg_applicable"
]]
# Out:
#                                              operator  ... cg_applicable
# 0   full_metrics_prog_k6_block_psd_reflection_hybr...  ...          True
# 1   illumination_prog_k6_block_psd_reflection_hybr...  ...          True
# 2   no_archive_prog_k6_block_psd_asymmetric_hybrid...  ...          True
# 3   structure_only_prog_k6_block_psd_reflection_mi...  ...          True
# 4   v12_1_cold_prog_k6_block_psd_asymmetric_min_ne...  ...          True
# 5   v12_1_random_prog_k6_block_psd_reflection_min_...  ...          True
# 6   v12_diagonal_prog_k6_diagonal_asymmetric_hybri...  ...          True
# 7                              reference_mole_k2_m200  ...         False
# 8                              reference_mole_k4_m200  ...         False
# 9                              reference_mole_k6_m200  ...         False
# 10                             reference_mole_k8_m200  ...         False
#
# [11 rows x 5 columns]

# %%
poisson = pd.read_csv(OUT / "tables" / "poisson_solver_comparison.csv")
poisson.loc[
    poisson["operator"].str.contains("reference_mole_k6"),
    [
        "operator", "cg_symmetric_part_diagnostic_relative_residual",
        "cg_symmetric_part_diagnostic_solution_error",
        "gmres_original_solution_error", "bicgstab_original_solution_error"
    ]
]
# Out:
#                  operator  ...  bicgstab_original_solution_error
# 9  reference_mole_k6_m200  ...                      1.007686e-09
#
# [1 rows x 5 columns]

# %% [markdown]
# The claim is availability and correctness of the certified SPD formulation. Exact Krylov iteration counts may vary across SciPy/BLAS builds and are not used for cross-family performance claims.
